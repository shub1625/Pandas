# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent') # To read the data from csv

# %%
filt = df['Country'] == 'India'
india_df = df.loc[filt]
india_df.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
#
#            CompFreq   CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 7           Monthly         NaN            NaN   India  United States dollar
# 22          Monthly         NaN            NaN   India          Indian rupee
# 58              NaN         NaN            NaN   India          Indian rupee
# 63              NaN         NaN            NaN   India                   NaN
# 149          Yearly  21000000.0       293196.0   India          Indian rupee
#
# ...

# %%
# write DF to csv
india_df.to_csv('data/modified_data.csv')

# %%
# To write into tab seprated file (tsv)
india_df.to_csv('data/modified.tsv', sep='\t')

# %%
# To write to xls format , do pip install xlwt openpyxl xlrd first
india_df.to_excel('data/modified.xlsx')

# %%
# To write to json format , default will be dict like , but if we want list like records we can pass orient argument
india_df.to_json('data/modified.json', orient='records' ,lines=True)

# %%
test = pd.read_json('data/modified.json', orient='records' ,lines=True)

# %%
test.head()
# Out:
#                                MainBranch Hobbyist   Age Age1stCode CompFreq  \
# 0          I am a developer by profession      Yes   NaN         18  Monthly
# 1          I am a developer by profession      Yes   NaN         18  Monthly
# 2          I am a developer by profession      Yes   NaN         22     None
# 3  I am a student who is learning to code      Yes  21.0         17     None
# 4          I am a developer by profession      Yes  36.0         31   Yearly
#
#     CompTotal  ConvertedComp Country          CurrencyDesc CurrencySymbol  \
# 0         NaN            NaN   India  United States dollar            USD
# 1         NaN            NaN   India          Indian rupee            INR
# 2         NaN            NaN   India          Indian rupee            INR
# 3         NaN            NaN   India                  None           None
# 4  21000000.0       293196.0   India          Indian rupee            INR
#
# ...

# %%
# To connect to postgres DB
# First install SQLAlchemy (it is an ORM for python)
# And for postgres pip install psycopg2-binary
# Now run below imports
from sqlalchemy import create_engine
import psycopg2

# %%
# create_engine will be used to connect to DB
# postgresql://dbname:dbpass@host_server:port_number/DBNAME
engine = create_engine('postgresql://postgres:dbpass@localhost:5432/pandas')

# %%
# Write data to DB
india_df.to_sql('sample_table', engine , if_exists='replace')

# %%
# read data
sql_df = pd.read_sql('sample_table',engine, index_col='Respondent')

# %%
sql_df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 7           I am a developer by profession      Yes  NaN         18  Monthly
# 22          I am a developer by profession      Yes  NaN         18  Monthly
#
#             CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 7                 NaN            NaN   India  United States dollar
# 22                NaN            NaN   India          Indian rupee
#
#            CurrencySymbol  ... SurveyEase           SurveyLength Trans  \
# Respondent                 ...
# 7                     USD  ...       None                   None  None
# 22                    INR  ...       Easy  Appropriate in length  None
#
#                                                UndergradMajor  \
# Respondent
# 7           Computer science, computer engineering, or sof...
# 22          Computer science, computer engineering, or sof...
#
# ...

# %%
# To read a paricular query 
# Note we have given "" for column names otherwise it will through error
# https://stackoverflow.com/questions/61018823/programmingerror-psycopg2-errors-undefinedcolumn-while-working-with-sqlalche
sql_df = pd.read_sql_query('SELECT "Hobbyist" , "CompFreq" FROM sample_table',engine)

# %%
# Out:
#      Hobbyist CompFreq
# 0         Yes  Monthly
# 1         Yes  Monthly
# 2         Yes     None
# 3         Yes     None
# 4         Yes   Yearly
# ...       ...      ...
# 8398      Yes     None
# 8399      Yes     None
# 8400      Yes     None
# 8401      Yes     None
# 8402      Yes     None
#
# [8403 rows x 2 columns]
